# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# @title Анализ обоснованности уровня цен на уголь в 2020 и 2021 годах, установленных компанией ООО "ТГРК"

# %%
os.getcwd()
# Out:
# '/content'

# %%
df = pd.read_excel("gdrive/MyDrive/coal.xlsx")
# Загрузили данные о финансово-хозяйственной деятельности ООО "ТГРК с 2010-2021 г

# %%
df.shape
# Out:
# (12, 8)

# %%
df.head(3)
# Out:
#    date   income  cost_of_sales  gross_profit  commercial_expenses  \
# 0  2010   949626         533011        416615                16466
# 1  2011  1136030         688948        447082                 3682
# 2  2012  1146610         583429        563182               140847
#
#    management_expenses  operating_profit  coal_price
# 0               189488            210661      1300.0
# 1               238310            205090      1560.0
# 2               204754            217581      1872.0

# %%
df3 = df.drop('date', axis = 1)

# %%
df3.corr() # Посмотрим не связаны ли между собой какие-либо переменные.
           # Из таблицы видно, что отсутствуют мультиколлинеарные данные, поэтому включим в модель все независимые переменные.
# Out:
#                        income  cost_of_sales  gross_profit  \
# income               1.000000       0.708317      0.780237
# cost_of_sales        0.708317       1.000000      0.111129
# gross_profit         0.780237       0.111129      1.000000
# commercial_expenses  0.758215       0.124894      0.956800
# management_expenses -0.507548      -0.766132     -0.035703
# operating_profit     0.430110       0.537240      0.129499
# coal_price           0.862071       0.747794      0.551071
#
#                      commercial_expenses  management_expenses  \
# income                          0.758215            -0.507548
# cost_of_sales                   0.124894            -0.766132
# gross_profit                    0.956800            -0.035703
# commercial_expenses             1.000000            -0.030225
# management_expenses            -0.030225             1.000000
# operating_profit               -0.068018            -0.752948
# ...

# %%
df1 = df[0:9]
X_train = df1.drop(['date','coal_price'], axis = 1)
# Выборка тренировочных данных для независимой переменных с 2010-2019 год
X_train
# Out:
#     income  cost_of_sales  gross_profit  commercial_expenses  \
# 0   949626         533011        416615                16466
# 1  1136030         688948        447082                 3682
# 2  1146610         583429        563182               140847
# 3  1023940         469224        554718               186127
# 4  1442860         573191        869670               437141
# 5  1509450         717987        791460               423742
# 6  1535550         722990        812560               384941
# 7  1626700         679861        946837               511684
# 8  1686730         797054        889680               440147
#
#    management_expenses  operating_profit
# 0               189488            210661
# 1               238310            205090
# 2               204754            217581
# 3               191068            177523
# 4               194876            237653
# 5               198491            169227
# 6               186308            241311
# ...

# %%
Y_train = df.iloc[0:9,7:8] # Выборка тренировочных данных для зависимых переменных с 2010-2019 год
Y_train
# Out:
#    coal_price
# 0     1300.00
# 1     1560.00
# 2     1872.00
# 3     1988.06
# 4     2093.42
# 5     2200.70
# 6     2365.90
# 7     2496.29
# 8     2596.00

# %%
df2 = df.iloc[10:12,0:-1]

# %%
X_test = df2.drop('date', axis = 1)
# Выборка тестовых независимых переменных, по которым будут предсказаны данные с 2020-2021
X_test
# Out:
#      income  cost_of_sales  gross_profit  commercial_expenses  \
# 10  1344060         813669        530387                94527
# 11  1556860         918809        638056               130365
#
#     management_expenses  operating_profit
# 10                80201            355659
# 11                85569            422122

# %%
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)

# %%
pred # Предсказанные цены на уголь 2020 и 2021 год
# Out:
# array([[1154.16004517],
#        [2111.6290101 ]])
